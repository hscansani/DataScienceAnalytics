# %% [markdown]
# <a href="https://colab.research.google.com/github/hscansani/DataScienceAnalytics/blob/main/Treino_DataAnalysis_YahooFinance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalando o Yahoo Finance (API)
! pip install yfinance

# %%
import pandas as pd
import numpy as np
import yfinance as yf
#Sobescreve os metodos do pandas datareader
yf.pdr_override()
import datetime as dt
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import csv

# %%
#Metodo para obtenção de dados da API
dfIbov = web.get_data_yahoo('^BVSP')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
#Exibir o inicio do dataframe
dfIbov.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 1993-04-27  24.799999  25.400000  24.500000  24.500000  24.500000       0
# 1993-04-28  24.500000  24.600000  23.700001  24.299999  24.299999       0
# 1993-04-29  24.299999  24.799999  23.700001  23.700001  23.700001       0
# 1993-04-30  23.700001  24.200001  23.700001  24.100000  24.100000       0
# 1993-05-03  24.100000  24.400000  23.799999  24.100000  24.100000       0

# %%
#plotando um gráfico de visualização dos fechamentos do IBOVESPA (default)
dfIbov['Close'].plot(figsize=(22,10))
# Out:
# <Axes: xlabel='Date'>

# %%
#MObtendo informações da bolsa do Mercado Livre
dfMeli = web.get_data_yahoo('MELI34.SA')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dfMeli.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2019-06-12  20.233334  20.233334  20.233334  20.233334  20.233334   87600
# 2019-06-13  20.233334  20.233334  20.233334  20.233334  20.233334       0
# 2019-06-14  19.963333  20.070000  19.963333  20.070000  20.070000  252000
# 2019-06-17  20.070000  20.070000  20.070000  20.070000  20.070000       0
# 2019-06-18  20.289165  20.289165  20.289165  20.289165  20.289165  612000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['Open'], **{})
# ...

# %%
#plotando um gráfico de visualização do Mercado Livre
dfMeli['Close'].plot(figsize=(22,10))
# Out:
# <Axes: xlabel='Date'>

# %%
#plotando um gráfico de visualização do Mercado Livre
dfMeli['Low'].plot(figsize=(22,10))
# Out:
# <Axes: xlabel='Date'>

# %%
#plotando um gráfico de visualização do Mercado Livre
dfMeli['Volume'].plot(figsize=(22,10))
# Out:
# <Axes: xlabel='Date'>
